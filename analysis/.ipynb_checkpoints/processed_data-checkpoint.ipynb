# %% [markdown]
# # CFD Processed Data

# %%
import numpy as np
import pandas as pd

from scipy.stats import spearmanr

import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the data sets

# %% [markdown]
# Setting the data paths:

# %%
CLARIFAI_OUTPUT_PATH = "../api_processing/Code/Clarifai/CFD/clarifai_output_corrected.csv"

# %%
FACEPP_OUTPUT_PATH = "../api_processing/Code/Face++/CFD/face++_output.csv"

# %%
MICROSOFT_OUTPUT_PATH = "../api_processing/Code/Microsoft/CFD/microsoft_output_corrected.csv"

# %%
AMAZON_OUTPUT_PATH = "../api_processing/Code/Amazon/CFD/amazon_output.csv"

# %% [markdown]
# Importing CSV outputs as Pandas data frames.

# %%
clarifai_raw = pd.read_csv(CLARIFAI_OUTPUT_PATH,header=0)
facepp_raw = pd.read_csv(FACEPP_OUTPUT_PATH,header=0)
microsoft_raw = pd.read_csv(MICROSOFT_OUTPUT_PATH,header=0)
amazon_raw = pd.read_csv(AMAZON_OUTPUT_PATH,header=0)

# %% [markdown]
# ## Browsing the data

# %% [markdown]
# Displaying the first 5 entries of the (sorted) table. Sorting is done to compare corresponding entries from the (File Name being the primary key of the entries).

# %% [markdown]
# ### Clarifai

# %%
clarifai_raw.sort_values(by=['File Name']).head()
# Out:
#                 File Name Target ID  Image ID Race Gender Expression  \
# 715  CFD-AF-200-228-N.jpg    AF-200       228    A      F          N
# 688  CFD-AF-201-060-N.jpg    AF-201        60    A      F          N
# 900  CFD-AF-202-122-N.jpg    AF-202       122    A      F          N
# 303  CFD-AF-203-077-N.jpg    AF-203        77    A      F          N
# 559  CFD-AF-204-067-N.jpg    AF-204        67    A      F          N
#
#     Clarifai Race  Race Confidence Clarifai Gender  Gender Confidence  \
# 715         asian         0.999892        feminine           0.995570
# 688         asian         0.998641       masculine           0.657457
# 900         asian         0.735281       masculine           0.780870
# 303         asian         0.998931        feminine           0.938326
# 559         asian         0.999699        feminine           0.919285
#
#      Clarifai Age  Age Confidence
# 715            39        0.764153
# 688            39        0.461942
# 900            39        0.587385
# 303            34        0.489016
# 559            38        0.703313

# %% [markdown]
# ### Face++

# %%
facepp_raw.sort_values(by=['File Name']).head()
# Out:
#                  File Name Target ID  Image ID Race Gender Expression  \
# 543   CFD-AF-200-228-N.jpg    AF-200       228    A      F          N
# 934   CFD-AF-201-060-N.jpg    AF-201        60    A      F          N
# 551   CFD-AF-202-122-N.jpg    AF-202       122    A      F          N
# 1147  CFD-AF-203-077-N.jpg    AF-203        77    A      F          N
# 1081  CFD-AF-204-067-N.jpg    AF-204        67    A      F          N
#
#      Face++ Gender  Face++ Age Face++ Emotion  Face++ Smiling
# 543         Female          48       surprise           False
# 934         Female          24        neutral           False
# 551           Male          30        neutral           False
# 1147        Female          26        neutral           False
# 1081        Female          20        sadness           False

# %% [markdown]
# ### Microsoft

# %%
microsoft_raw.sort_values(by=['File Name']).head()
# Out:
#                  File Name Target ID  Image ID Race Gender Expression  \
# 459   CFD-AF-200-228-N.jpg    AF-200       228    A      F          N
# 380   CFD-AF-201-060-N.jpg    AF-201        60    A      F          N
# 933   CFD-AF-202-122-N.jpg    AF-202       122    A      F          N
# 993   CFD-AF-203-077-N.jpg    AF-203        77    A      F          N
# 1009  CFD-AF-204-067-N.jpg    AF-204        67    A      F          N
#
#      Microsoft Gender  Microsoft Age Microsoft Emotion  Microsoft Smiling
# 459            female           32.0           neutral                0.0
# 380            female           22.0           neutral                0.0
# 933            female           22.0           neutral                0.0
# 993            female           19.0           neutral                0.0
# 1009           female           28.0           neutral                0.0

# %% [markdown]
# ### Amazon

# %%
amazon_raw.sort_values(by=['File Name']).head()
# Out:
#                  File Name Target ID  Image ID Race Gender Expression  \
# 459   CFD-AF-200-228-N.jpg    AF-200       228    A      F          N
# 380   CFD-AF-201-060-N.jpg    AF-201        60    A      F          N
# 933   CFD-AF-202-122-N.jpg    AF-202       122    A      F          N
# 993   CFD-AF-203-077-N.jpg    AF-203        77    A      F          N
# 1009  CFD-AF-204-067-N.jpg    AF-204        67    A      F          N
#
#       age_low  age_high  smile_value  smile_confidence gender_value  \
# 459        22        34        False         96.689507       Female
# 380        22        34        False         98.795700       Female
# 933        22        34        False         99.194702       Female
# 993        20        32        False         96.263527       Female
# 1009       22        34        False         99.297867       Female
#
#       gender_confidence top_emotion
# 459           98.523636   SURPRISED
# 380           93.703087        CALM
# 933           91.597496        CALM
# 993           87.574516       ANGRY
# 1009          99.072227        CALM

# %% [markdown]
# #### Displaying basic statistics about the sets:

# %%
clarifai_raw.describe(include = [np.object, np.number, np.bool])
# Out:
#                    File Name Target ID     Image ID  Race Gender Expression  \
# count                   1207      1207  1207.000000  1207   1207       1207
# unique                  1207       597          NaN     4      2          5
# top     CFD-WF-035-019-F.jpg    WF-007          NaN     B      F          N
# freq                       1         5          NaN   526    644        597
# mean                     NaN       NaN    59.386910   NaN    NaN        NaN
# std                      NaN       NaN    69.992716   NaN    NaN        NaN
# min                      NaN       NaN     1.000000   NaN    NaN        NaN
# 25%                      NaN       NaN     9.000000   NaN    NaN        NaN
# 50%                      NaN       NaN    26.000000   NaN    NaN        NaN
# 75%                      NaN       NaN    88.000000   NaN    NaN        NaN
# max                      NaN       NaN   357.000000   NaN    NaN        NaN
#
#                     Clarifai Race  Race Confidence Clarifai Gender  \
# count                        1207      1207.000000            1207
# unique                          6              NaN               2
# top     black or african american              NaN       masculine
# freq                          490              NaN             713
# mean                          NaN         0.882580             NaN
# std                           NaN         0.190902             NaN
# min                           NaN         0.213848             NaN
# 25%                           NaN         0.840955             NaN
# 50%                           NaN         0.989538             NaN
# 75%                           NaN         0.999417             NaN
# max                           NaN         1.000000             NaN
#
#         Gender Confidence  Clarifai Age  Age Confidence
# count         1207.000000   1207.000000     1207.000000
# unique                NaN           NaN             NaN
# top                   NaN           NaN             NaN
# freq                  NaN           NaN             NaN
# mean             0.916526     36.070423        0.574756
# std              0.127730      8.096281        0.116007
# min              0.501260      1.000000        0.261275
# 25%              0.886580     34.000000        0.491227
# 50%              0.987086     39.000000        0.566697
# 75%              0.998416     39.000000        0.652895
# max              0.999999     71.000000        0.983919

# %% [markdown]
# **Problem**: The statistics are not very useful, because most of the categories are represented by strings, not numbers. Let's replace strings with numerical values.

# %% [markdown]
# ## Standardizing Values
# We need to turn `String` values into numerical values.

# %% [markdown]
# Let's extract the Chicago Fire Dataset features in a dictionary. We are now going to try to adjust the mapping of the API values to this one.

# %%
chicago_features = {
    'Race' : {'A': 0, 'W': 1, 'L': 2, 'B': 3}, 
    'Gender': {'F': 0, 'M': 1}, 
    'Expression': {'N': 0, 'A': 1, 'HO': 2, 'HC': 2, 'F': 3}
}

# %% [markdown]
# **Note:** HO and HC are basically the same emotion, so we map them to the same value.

# %%
clarifai_features = {
    'Clarifai Race': {
        'asian': 0, 
        'white': 1,
        'hispanic, latino, or spanish origin': 2, 
        'black or african american': 3,
        'american indian or alaska native': 5, 
        'middle eastern or north african': 6
    }, 
    'Clarifai Gender': {'feminine': 0, 'masculine': 1}, 
}

# %%
facepp_features = {
    "Face++ Gender": {'Female': 0, 'Male': 1},
    "Face++ Emotion": {
        'neutral': 0,
        'anger': 1,
        'happiness': 2,
        'fear': 3,
        'surprise': 4,
        'disgust': 5,
        'sadness': 6
    },
    "Face++ Smiling": {False: 0, True: 1}
}

# %%
amazon_features = {
    "smile_value": {False: 0, True: 1}, 
    "gender_value": {"Female": 0, "Male": 1}, 
    "top_emotion" : {"CALM": 0, "ANGRY": 1, "HAPPY": 2, "FEAR": 3, 
                     "SURPRISED": 4, "DISGUSTED": 5, "SAD": 6, "CONFUSED": 8}
}

# %%
microsoft_features = {
    "Microsoft Gender": {"female": 0, "male": 1}, 
    "Microsoft Emotion": {"neutral": 0, "anger": 1, "happiness": 2, "fear": 3,
                          "surprise": 4, "disgust": 5, "sadness": 6, "contempt": 7}
}

# %%
facepp = facepp_raw.copy()
for field in {**chicago_features, **facepp_features}: 
    facepp[field] = facepp_raw[field].map({**chicago_features, **facepp_features}[field])

# %%
clarifai = clarifai_raw.copy()
for field in {**chicago_features, **clarifai_features}: 
    clarifai[field] = clarifai_raw[field].map({**chicago_features, **clarifai_features}[field])

# %%
# facepp = facepp_raw.copy()
# for field in {**chicago_features, **facepp_features}: 
#     facepp[field] = facepp_raw[field].map({**chicago_features, **facepp_features}[field])

# %%
# facepp = facepp_raw.copy()
# for field in {**chicago_features, **facepp_features}: 
#     facepp[field] = facepp_raw[field].map({**chicago_features, **facepp_features}[field])

# %%
facepp.head()
# Out:
#                File Name Target ID  Image ID  Race  Gender  Expression  \
# 0   CFD-BM-015-012-A.jpg    BM-015        12     3       1           1
# 1   CFD-BF-039-031-N.jpg    BF-039        31     3       0           0
# 2  CFD-BF-048-006-HC.jpg    BF-048         6     3       0           2
# 3   CFD-AM-218-085-N.jpg    AM-218        85     0       1           0
# 4   CFD-AF-249-092-N.jpg    AF-249        92     0       0           0
#
#    Face++ Gender  Face++ Age  Face++ Emotion  Face++ Smiling
# 0              1          38               1               0
# 1              0          24               0               0
# 2              0          52               2               1
# 3              1          42               0               0
# 4              0          35               4               0

# %%
clarifai.head()
# Out:
#               File Name Target ID  Image ID  Race  Gender  Expression  \
# 0  CFD-LF-212-066-N.jpg    LF-212        66     2       0           0
# 1  CFD-BF-205-141-N.jpg    BF-205       141     3       0           0
# 2  CFD-WF-030-002-N.jpg    WF-030         2     1       0           0
# 3  CFD-WF-001-003-N.jpg    WF-001         3     1       0           0
# 4  CFD-LF-239-148-N.jpg    LF-239       148     2       0           0
#
#    Clarifai Race  Race Confidence  Clarifai Gender  Gender Confidence  \
# 0              0         0.446271                0           0.883454
# 1              3         0.999764                1           0.931101
# 2              1         0.887473                1           0.553333
# 3              1         0.966461                1           0.955751
# 4              2         0.429596                0           0.833086
#
#    Clarifai Age  Age Confidence
# 0             1        0.917314
# 1             1        0.450996
# 2             1        0.474595
# 3             1        0.527979
# 4             1        0.740188

# %% [markdown]
# Now, let's add a few new features indicating correct or incorrect misclassification.

# %%
clarifai["Gender Classification"] = 0

for index, row in clarifai.iterrows(): 
    if row["Gender"] == row["Clarifai Gender"]:
        clarifai.at[index, 'Gender Classification'] = 1

# %%
facepp["Gender Classification"] = 0

for index, row in facepp.iterrows(): 
    if row["Gender"] == row["Face++ Gender"]:
        facepp.at[index, 'Gender Classification'] = 1

# %% [markdown]
# Finally, the tables look as follows:

# %%
clarifai.head()
# Out:
#               File Name Target ID  Image ID  Race  Gender  Expression  \
# 0  CFD-LF-212-066-N.jpg    LF-212        66     2       0           0
# 1  CFD-BF-205-141-N.jpg    BF-205       141     3       0           0
# 2  CFD-WF-030-002-N.jpg    WF-030         2     1       0           0
# 3  CFD-WF-001-003-N.jpg    WF-001         3     1       0           0
# 4  CFD-LF-239-148-N.jpg    LF-239       148     2       0           0
#
#    Clarifai Race  Race Confidence  Clarifai Gender  Gender Confidence  \
# 0              0         0.446271                0           0.883454
# 1              3         0.999764                1           0.931101
# 2              1         0.887473                1           0.553333
# 3              1         0.966461                1           0.955751
# 4              2         0.429596                0           0.833086
#
#    Clarifai Age  Age Confidence
# 0             1        0.917314
# 1             1        0.450996
# 2             1        0.474595
# 3             1        0.527979
# 4             1        0.740188

# %%
facepp.head()
# Out:
#                File Name Target ID  Image ID  Race  Gender  Expression  \
# 0   CFD-BM-015-012-A.jpg    BM-015        12     3       1           1
# 1   CFD-BF-039-031-N.jpg    BF-039        31     3       0           0
# 2  CFD-BF-048-006-HC.jpg    BF-048         6     3       0           2
# 3   CFD-AM-218-085-N.jpg    AM-218        85     0       1           0
# 4   CFD-AF-249-092-N.jpg    AF-249        92     0       0           0
#
#    Face++ Gender  Face++ Age  Face++ Emotion  Face++ Smiling
# 0              1          38               1               0
# 1              0          24               0               0
# 2              0          52               2               1
# 3              1          42               0               0
# 4              0          35               4               0

# %% [markdown]
# And the statistics:

# %%
clarifai.describe()
# Out:
#           Image ID         Race       Gender   Expression  Clarifai Race  \
# count  1207.000000  1207.000000  1207.000000  1207.000000    1207.000000
# mean     59.386910     1.870754     0.466446     1.006628       1.829329
# std      69.992716     1.079677     0.499080     1.115230       1.200070
# min       1.000000     0.000000     0.000000     0.000000       0.000000
# 25%       9.000000     1.000000     0.000000     0.000000       1.000000
# 50%      26.000000     2.000000     0.000000     1.000000       2.000000
# 75%      88.000000     3.000000     1.000000     2.000000       3.000000
# max     357.000000     3.000000     1.000000     3.000000       6.000000
#
#        Race Confidence  Clarifai Gender  Gender Confidence  Clarifai Age  \
# count      1207.000000      1207.000000        1207.000000   1207.000000
# mean          0.882580         0.590721           0.916526     36.070423
# std           0.190902         0.491905           0.127730      8.096281
# min           0.213848         0.000000           0.501260      1.000000
# 25%           0.840955         0.000000           0.886580     34.000000
# 50%           0.989538         1.000000           0.987086     39.000000
# 75%           0.999417         1.000000           0.998416     39.000000
# max           1.000000         1.000000           0.999999     71.000000
#
#        Age Confidence
# count     1207.000000
# mean         0.574756
# std          0.116007
# min          0.261275
# 25%          0.491227
# 50%          0.566697
# 75%          0.652895
# max          0.983919

# %%
facepp.describe()
# Out:
#           Image ID         Race       Gender   Expression  Face++ Gender  \
# count  1207.000000  1207.000000  1207.000000  1207.000000    1207.000000
# mean     59.386910     1.870754     0.466446     1.006628       0.529412
# std      69.992716     1.079677     0.499080     1.115230       0.499341
# min       1.000000     0.000000     0.000000     0.000000       0.000000
# 25%       9.000000     1.000000     0.000000     0.000000       0.000000
# 50%      26.000000     2.000000     0.000000     1.000000       1.000000
# 75%      88.000000     3.000000     1.000000     2.000000       1.000000
# max     357.000000     3.000000     1.000000     3.000000       1.000000
#
#         Face++ Age  Face++ Emotion  Face++ Smiling
# count  1207.000000     1207.000000     1207.000000
# mean     34.662800        1.444076        0.318144
# std       9.429399        1.740641        0.465949
# min      18.000000        0.000000        0.000000
# 25%      28.000000        0.000000        0.000000
# 50%      33.000000        1.000000        0.000000
# 75%      41.000000        2.000000        1.000000
# max      73.000000        6.000000        1.000000

# %% [markdown]
# ### 3. Spearman test for Clarifai

# %%
gender_classification = np.array(clarifai["Gender Classification"]).reshape(-1,1)
race = np.array(clarifai["Race"]).reshape(-1,1)
gender = np.array(clarifai["Gender"]).reshape(-1,1)

race_and_genderclass = np.concatenate([race, gender_classification], axis=1)
race_and_gender = np.concatenate([race, gender], axis=1)

# %% [markdown]
# **Note:** we can pass both arrays separately or together as a matrix.

# %%
spearmanr(race, gender_classification)

# %%
spearmanr(race_and_genderclass)

# %%
spearmanr(gender, gender_classification)

# %%
rho, p = spearmanr(race_and_gender, gender_classification)
rho

# %%
misclassified_women = clarifai[(clarifai["Gender"]==0) & (clarifai["Gender Classification"]==0)]
misclassified_men = clarifai[(clarifai["Gender"]==1) & (clarifai["Gender Classification"]==0)]

# %%
print("# of misclassified women: ", len(misclassified_women))
print("# of misclassified men: ", len(misclassified_men))

# %%
misclassified_black_women = clarifai[(clarifai["Gender"]==0) 
                                     & (clarifai["Gender Classification"]==0)
                                     & (clarifai["Race"]==3)]
misclassified_white_women = clarifai[(clarifai["Gender"]==0) 
                                     & (clarifai["Gender Classification"]==0)
                                     & (clarifai["Race"]==1)]

# %%
print("# of misclassified black women: ", len(misclassified_black_women))
print("# of misclassified white women: ", len(misclassified_white_women))

# %% [markdown]
# TODO: Recompute Spearman with gender (for race)

# %% [markdown]
# ### 4. Spearman test for Face++

# %%
fpp_gender_classification = np.array(facepp["Gender Classification"]).reshape(-1,1)
fpp_race = np.array(facepp["Race"]).reshape(-1,1)
fpp_gender = np.array(facepp["Gender"]).reshape(-1,1)

# %%
spearmanr(fpp_race, fpp_gender_classification)

# %%
spearmanr(fpp_gender, fpp_gender_classification)

# %%
fpp_misclassified_women = facepp[(facepp["Gender"]==0) & (facepp["Gender Classification"]==0)]
fpp_misclassified_men = facepp[(facepp["Gender"]==1) & (facepp["Gender Classification"]==0)]\

# %%
print("# of misclassified women: ", len(fpp_misclassified_women))
print("# of misclassified men: ", len(fpp_misclassified_men))

# %%
fpp_misclassified_black_women = facepp[(facepp["Gender"]==0) 
                                     & (facepp["Gender Classification"]==0)
                                     & (facepp["Race"]==3)]
fpp_misclassified_white_women = facepp[(facepp["Gender"]==0) 
                                     & (facepp["Gender Classification"]==0)
                                     & (facepp["Race"]==1)]

# %%
print("# of misclassified black women: ", len(fpp_misclassified_black_women))
print("# of misclassified white women: ", len(fpp_misclassified_white_women))

# %% [markdown]
# TODO: Exclude repetitions
